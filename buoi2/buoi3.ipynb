# %% [markdown]
# TUẦN 3 : NUMPY, PANDAS, MATPLOTLIB
# Pandas là một thư viện tương đối mới, được xây dựng dựa trên NumPy, và cung cấp một cách cài đặt hiệu quả cho cấu trúc dữ liệu DataFrame.
#
# DataFrame về bản chất là các mảng đa chiều (multidimensional arrays) có gắn nhãn hàng (row labels) và nhãn cột (column labels), đồng thời thường chứa dữ liệu không đồng nhất về kiểu (heterogeneous types) và/hoặc giá trị bị thiếu (missing data).
#
# Bằng việc cung cấp một giao diện lưu trữ thuận tiện cho dữ liệu có nhãn (labeled data), Pandas triển khai nhiều phép toán xử lý dữ liệu mạnh mẽ, quen thuộc với người dùng các hệ quản trị cơ sở dữ liệu (database frameworks) cũng như các chương trình bảng tính (spreadsheet programs).
#
# Mặc dù cấu trúc dữ liệu ndarray của NumPy cung cấp các tính năng nền tảng quan trọng, nhưng những hạn chế của nó trở nên rõ ràng khi cần sự linh hoạt cao hơn, chẳng hạn như gắn nhãn cho dữ liệu, xử lý dữ liệu bị thiếu, v.v.
#
# Pandas cung cấp khả năng truy cập và xử lý hiệu quả các tác vụ “data munging” (tiền xử lý, làm sạch và biến đổi dữ liệu) — những công việc chiếm phần lớn thời gian làm việc.

# %%
import pandas as pd
pd.__version__

# %% [markdown]
# -----
# Series
#
# Pandas Series là một mảng một chiều (one-dimensional array) có chỉ mục (index).
#
# Series có thể được khởi tạo từ một danh sách (list) hoặc một mảng (array) như sau:
#
# Tạo Series từ list

# %% [markdown]
# Tạo Series từ list

# %%
data_pd = pd.Series([0.5, 0.3, 1.0, 2.5])
data_pd
# Out:
# 0    0.5
# 1    0.3
# 2    1.0
# 3    2.5
# dtype: float64

# %% [markdown]
# Tạo Series từ Numpy array

# %%
import numpy as np
S = 4
numpy_arr = np.arange(S)
data_pd = pd.Series(numpy_arr)
data_pd
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int32

# %% [markdown]
# Attributes

# %%
data_pd.values
# Out:
# array([0, 1, 2, 3])

# %%
data_pd.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# indexing

# %%
data_pd[1]
# Out:
# 1

# %%
data_pd[-2:]
# Out:
# 2    2
# 3    3
# dtype: int32

# %%
data_pd[-1] #khong co chi so index = -1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Program Files\Python39\lib\site-packages\pandas\core\indexes\range.py:351, in RangeIndex.get_loc(self, key, method, tolerance)
#     350 try:
# --> 351     return self._range.index(new_key)
#     352 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data_pd[-1] #khong co chi so index = -1
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\series.py:853, in Series.__getitem__(self, key)
#     850     return self._values[key]
#     852 elif key_is_scalar:
# --> 853     return self._get_value(key)
#     855 if is_hashable(key):
#     856     # Otherwise index.get_value will raise InvalidIndexError
#     857     try:
#     858         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\series.py:961, in Series._get_value(self, label, takeable)
#     958     return self._values[label]
#     960 # Similar to Index.get_value, but we do not fall back to positional
# --> 961 loc = self.index.get_loc(label)
#     962 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\indexes\range.py:353, in RangeIndex.get_loc(self, key, method, tolerance)
#     351             return self._range.index(new_key)
#     352         except ValueError as err:
# --> 353             raise KeyError(key) from err
#     354     raise KeyError(key)
#     355 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: -1

# %% [markdown]
# letter indexing

# %%
#chi so nguyen kho ding => thu doi sang chu cai
data_pd = pd.Series([1.25,2.0,0.75,1.0], index = ['a','b','c','d'])

# %%
data_pd[-1]
# Out:
# 1.0

# %%
data_pd['b']
# Out:
# 2.0

# %% [markdown]
# BTVN1
# Giải thích hiện tượng trên

# %% [markdown]
# Combined Indexing

# %%
index = ['a','b','c','d',3]
data_pd = pd.Series(numpy_arr, index=index)

# %%
data_pd['a']
# Out:
# 0

# %%
data_pd[3]
# Out:
# 4

# %% [markdown]
# panpas and dictionary

# %%
#he thong chi muc cua pandas co cau truc tuong tu Dictionary
#viec tao 1 doi tuong pandas tu Dictionary la dieu hoan toan de hieu
some_poppulation_dict = {'SaiGon' : 59,
                         'Dong Nai' : 60,
                         'Binh Thuan' : 86,
                         'Ha Noi' : 29}
data_pd = pd.Series(some_poppulation_dict)
data_pd['SaiGon']
# Out:
# 59

# %%
#Pandas cung ho tro slising
#luu y : slising theo index label la "bao gom ca diem ket thuc"
data_pd['SaiGon':'Ha Noi']
# Out:
# SaiGon        59
# Dong Nai      60
# Binh Thuan    86
# Ha Noi        29
# dtype: int64

# %% [markdown]
# pandas and scalar

# %%
#du lieu co the la mot gia tri vo huong (scalar)
#va gia tri nay se duoc lap lai de dien vao toan bo index da chi dinh
data_pd = pd.Series(5, index=[2,3,8])
data_pd
# Out:
# 2    5
# 3    5
# 8    5
# dtype: int64

# %% [markdown]
# dataframe
#
# DataFrame tương tự mảng 2 chiều, với index hàng và tên cột linh hoạt; về bản chất là tập hợp các Series được căn chỉnh theo index.

# %% [markdown]
# Tạo dataframe với 2 dict

# %%
some_poppulation_dict = {'SaiGon' : 5152,
                         'Dong Nai' : 6000,
                         'Binh Thuan' : 8386,
                         'Ha Noi' : 2979}
some_area_dict = {'SaiGon' : 51,
                         'Dong Nai' : 60,
                         'Binh Thuan' : 86,
                         'Ha Noi' : 29,
                         'Vung Tau':72}
state = pd.DataFrame({'Poppulation' :some_poppulation_dict,'Area' :some_area_dict})
state
# Out:
#             Poppulation  Area
# SaiGon           5152.0    51
# Dong Nai         6000.0    60
# Binh Thuan       8386.0    86
# Ha Noi           2979.0    29
# Vung Tau            NaN    72

# %%
state['SaiGon': 'Ha Noi']
# Out:
#             Poppulation  Area
# SaiGon           5152.0    51
# Dong Nai         6000.0    60
# Binh Thuan       8386.0    86
# Ha Noi           2979.0    29

# %%
state['SaiGon': 'Ha Noi']['Poppulation']
# Out:
# SaiGon        5152.0
# Dong Nai      6000.0
# Binh Thuan    8386.0
# Ha Noi        2979.0
# Name: Poppulation, dtype: float64

# %%
state['Poppulation']['SaiGon': 'Ha Noi'] #khong quan trong thu tu
# Out:
# SaiGon        5152.0
# Dong Nai      6000.0
# Binh Thuan    8386.0
# Ha Noi        2979.0
# Name: Poppulation, dtype: float64

# %%
state['SaiGon': 'Ha Noi']['Poppulation']['Area'] #cot area khong ton tai
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Python39\lib\site-packages\pandas\core\indexes\base.py:3080, in Index.get_loc(self, key, method, tolerance)
#    3079 try:
# -> 3080     return self._engine.get_loc(casted_key)
#    3081 except KeyError as err:
#
# File pandas\_libs\index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:4554, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:4562, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 state['SaiGon': 'Ha Noi']['Poppulation']['Area']
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\series.py:853, in Series.__getitem__(self, key)
#     850     return self._values[key]
#     852 elif key_is_scalar:
# --> 853     return self._get_value(key)
#     855 if is_hashable(key):
#     856     # Otherwise index.get_value will raise InvalidIndexError
#     857     try:
#     858         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\series.py:961, in Series._get_value(self, label, takeable)
#     958     return self._values[label]
#     960 # Similar to Index.get_value, but we do not fall back to positional
# --> 961 loc = self.index.get_loc(label)
#     962 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Program Files\Python39\lib\site-packages\pandas\core\indexes\base.py:3082, in Index.get_loc(self, key, method, tolerance)
#    3080         return self._engine.get_loc(casted_key)
#    3081     except KeyError as err:
# -> 3082         raise KeyError(key) from err
#    3084 if tolerance is not None:
#    3085     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: 'Area'

# %%
state['Area']
# Out:
# SaiGon        51
# Dong Nai      60
# Binh Thuan    86
# Ha Noi        29
# Vung Tau      72
# Name: Area, dtype: int64

# %%
state[:]['Area']
# Out:
# SaiGon        51
# Dong Nai      60
# Binh Thuan    86
# Ha Noi        29
# Vung Tau      72
# Name: Area, dtype: int64

# %% [markdown]
# Attributes

# %%
state.index
# Out:
# Index(['SaiGon', 'Dong Nai', 'Binh Thuan', 'Ha Noi', 'Vung Tau'], dtype='object')

# %%
state.index[-1]
# Out:
# 'Vung Tau'

# %%
state.columns
# Out:
# Index(['Poppulation', 'Area'], dtype='object')

# %%
state.columns[0:1]
# Out:
# Index(['Poppulation'], dtype='object')

# %% [markdown]
# Series indexing/slicing/fancy indexing

# %%
import pandas as pd
data = pd.Series([0.75,0.5,1.0,2.0],
                 index = ['a','b','c','d'])
data
# Out:
# a    0.75
# b    0.50
# c    1.00
# d    2.00
# dtype: float64

# %% [markdown]
# explicit vs implicit index

# %%
data['b']
# Out:
# 0.5

# %%
data[-1]
# Out:
# 2.0

# %%
data['a':'c']
# Out:
# a    0.75
# b    0.50
# c    1.00
# dtype: float64

# %%
data[0:2]
# Out:
# a    0.75
# b    0.50
# dtype: float64

# %% [markdown]
# adding values

# %%
data['e'] = 10
data
# Out:
# a     0.75
# b     0.50
# c     1.00
# d     2.00
# e    10.00
# dtype: float64

# %% [markdown]
# in

# %%
'a' in data
# Out:
# True

# %%
'f' in data
# Out:
# False

# %% [markdown]
# key()

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# items

# %%
list(data.items())
# Out:
# [('a', 0.75), ('b', 0.5), ('c', 1.0), ('d', 2.0), ('e', 10.0)]

# %% [markdown]
# values()

# %%
data.values
# Out:
# array([ 0.75,  0.5 ,  1.  ,  2.  , 10.  ])

# %% [markdown]
# masking

# %%
data[(data > 0.5) & (data <10)]
# Out:
# a    0.75
# c    1.00
# d    2.00
# dtype: float64

# %% [markdown]
# fancy indexing

# %%
data[['a','e']]
# Out:
# a     0.75
# e    10.00
# dtype: float64
